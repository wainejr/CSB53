# %%
from typing import List

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_theme()

# %%
filename = "../data/all_data.json"
#filename = "csb-53/data/all_data.json"

df = pd.read_json(filename, convert_dates=["release_date"])
df.set_index("link_album")

# Limit number of metacritic only albums, to not unbalance the model
df_metacritic = df.groupby([df["release_date"].dt.year]).apply(lambda grp: grp.nlargest(50, 'metascore'))

df = df[df["billboard"].notnull()
        | df["grammy"].notnull()
        | df["link_album"].isin(df_metacritic["link_album"].unique())]
df
# Out:
#                  artist               album release_date  userscore  \
# 0             Sigur Rós                  ()   2002-10-29       88.0
# 1            Ed Sheeran              Divide   2017-03-03       47.0
# 2            Ed Sheeran                   +   2012-06-12       76.0
# 3                 Jewel                0304   2003-06-03       63.0
# 6                   Sia  1000 Forms of Fear   2014-07-08       89.0
# ...                 ...                 ...          ...        ...
# 3240              Logic                YSIV   2018-09-28       71.0
# 3241      Joanna Newsom                  Ys   2006-11-14       84.0
# 3242  Smashing Pumpkins           Zeitgeist   2007-07-10       77.0
# 3244       Denzel Curry                 ZUU   2019-05-31       80.0
# 3245  My Morning Jacket                   Z   2005-10-04       84.0
#
#       metascore                                         link_album  \
# 0            82      https://www.metacritic.com/music/()/sigur-ros
# 1            62  https://www.metacritic.com/music/(divide)/ed-s...
# 2            67      https://www.metacritic.com/music/+/ed-sheeran
# 3            63        https://www.metacritic.com/music/0304/jewel
# 6            76  https://www.metacritic.com/music/1000-forms-of...
# ...         ...                                                ...
# 3240         71        https://www.metacritic.com/music/ysiv/logic
# 3241         85  https://www.metacritic.com/music/ys/joanna-newsom
# 3242         59  https://www.metacritic.com/music/zeitgeist/the...
# 3244         85  https://www.metacritic.com/music/zuu/denzel-curry
# 3245         90  https://www.metacritic.com/music/z/my-morning-...
#
#                                                link_img  \
# 0     https://static.metacritic.com/images/products/...
# 1     https://static.metacritic.com/images/products/...
# 2     https://static.metacritic.com/images/products/...
# 3     https://static.metacritic.com/images/products/...
# 6     https://static.metacritic.com/images/products/...
# ...                                                 ...
# 3240  https://static.metacritic.com/images/products/...
# 3241  https://static.metacritic.com/images/products/...
# 3242  https://static.metacritic.com/images/products/...
# 3244  https://static.metacritic.com/images/products/...
# 3245  https://static.metacritic.com/images/products/...
#
#                                            genres grammy  \
# 0                                   [Indie, Rock]   None
# 1                                      [Pop/Rock]   None
# 2                                      [Pop/Rock]   None
# 3     [Pop, Adult Alternative, Singer-Songwriter]   None
# 6                        [Electronic, Club/Dance]   None
# ...                                           ...    ...
# 3240             [Rap, Pop-Rap, Contemporary Rap]   None
# 3241                          [Indie, Rock, Folk]   None
# 3242                          [Rock, Alternative]   None
# 3244                                        [Rap]   None
# 3245                                [Indie, Rock]   None
#
#                                               billboard
# 0                                                  None
# 1        {'2017': 4, '2018': 5, '2019': 31, '2020': 65}
# 2     {'2012': 136, '2013': 46, '2014': 122, '2015':...
# 3                                         {'2003': 110}
# 6                {'2014': 131, '2015': 40, '2016': 129}
# ...                                                 ...
# 3240                                      {'2018': 177}
# 3241                                               None
# 3242                                      {'2007': 165}
# 3244                                               None
# 3245                                               None
#
# [2247 rows x 10 columns]

# %%
df_genres_wrapped = df[["genres", "artist", "album", "link_album"]]
df_genres_wrapped
# Out:
#                                            genres             artist  \
# 0                                   [Indie, Rock]          Sigur Rós
# 1                                      [Pop/Rock]         Ed Sheeran
# 2                                      [Pop/Rock]         Ed Sheeran
# 3     [Pop, Adult Alternative, Singer-Songwriter]              Jewel
# 6                        [Electronic, Club/Dance]                Sia
# ...                                           ...                ...
# 3240             [Rap, Pop-Rap, Contemporary Rap]              Logic
# 3241                          [Indie, Rock, Folk]      Joanna Newsom
# 3242                          [Rock, Alternative]  Smashing Pumpkins
# 3244                                        [Rap]       Denzel Curry
# 3245                                [Indie, Rock]  My Morning Jacket
#
#                    album                                         link_album
# 0                     ()      https://www.metacritic.com/music/()/sigur-ros
# 1                 Divide  https://www.metacritic.com/music/(divide)/ed-s...
# 2                      +      https://www.metacritic.com/music/+/ed-sheeran
# 3                   0304        https://www.metacritic.com/music/0304/jewel
# 6     1000 Forms of Fear  https://www.metacritic.com/music/1000-forms-of...
# ...                  ...                                                ...
# 3240                YSIV        https://www.metacritic.com/music/ysiv/logic
# 3241                  Ys  https://www.metacritic.com/music/ys/joanna-newsom
# 3242           Zeitgeist  https://www.metacritic.com/music/zeitgeist/the...
# 3244                 ZUU  https://www.metacritic.com/music/zuu/denzel-curry
# 3245                   Z  https://www.metacritic.com/music/z/my-morning-...
#
# [2247 rows x 4 columns]

# %% [markdown]
# # Unwrap genres

# %%
all_albums = []
for v in df_genres_wrapped.values:
    # each genre
    if(v[0] is not None):
        for g in v[0]:
            all_albums.append((g, v[1], v[2], v[3]))
df_genres = pd.DataFrame(all_albums, columns=["genre", "artist", "album", "link_album"])
df_genres
# Out:
#             genre             artist      album  \
# 0           Indie          Sigur Rós         ()
# 1            Rock          Sigur Rós         ()
# 2        Pop/Rock         Ed Sheeran     Divide
# 3        Pop/Rock         Ed Sheeran          +
# 4             Pop              Jewel       0304
# ...           ...                ...        ...
# 5453         Rock  Smashing Pumpkins  Zeitgeist
# 5454  Alternative  Smashing Pumpkins  Zeitgeist
# 5455          Rap       Denzel Curry        ZUU
# 5456        Indie  My Morning Jacket          Z
# 5457         Rock  My Morning Jacket          Z
#
#                                              link_album
# 0         https://www.metacritic.com/music/()/sigur-ros
# 1         https://www.metacritic.com/music/()/sigur-ros
# 2     https://www.metacritic.com/music/(divide)/ed-s...
# 3         https://www.metacritic.com/music/+/ed-sheeran
# 4           https://www.metacritic.com/music/0304/jewel
# ...                                                 ...
# 5453  https://www.metacritic.com/music/zeitgeist/the...
# 5454  https://www.metacritic.com/music/zeitgeist/the...
# 5455  https://www.metacritic.com/music/zuu/denzel-curry
# 5456  https://www.metacritic.com/music/z/my-morning-...
# 5457  https://www.metacritic.com/music/z/my-morning-...
#
# [5458 rows x 4 columns]

# %% [markdown]
# # Filter genres

# %%
N_GENRES = 30

count_values = df_genres.value_counts(["genre"])
bef_genres = len(count_values)
bef_df = len(df_genres)

genres_get = df_genres.value_counts(["genre"]).nlargest(N_GENRES)
genres_get = [g[0] for g in list(genres_get.index)]
df_genres = df_genres[df_genres["genre"].isin(genres_get)]

count_values = df_genres.value_counts(["genre"])

after_genres = len(count_values)
after_df = len(df_genres)
print(f"Genres: {bef_genres} -> {after_genres}")
print(f"DF: {bef_df} -> {after_df}")

df_genres
# Out:
# Genres: 277 -> 30
# DF: 5458 -> 4355
#             genre             artist      album  \
# 0           Indie          Sigur Rós         ()
# 1            Rock          Sigur Rós         ()
# 2        Pop/Rock         Ed Sheeran     Divide
# 3        Pop/Rock         Ed Sheeran          +
# 4             Pop              Jewel       0304
# ...           ...                ...        ...
# 5453         Rock  Smashing Pumpkins  Zeitgeist
# 5454  Alternative  Smashing Pumpkins  Zeitgeist
# 5455          Rap       Denzel Curry        ZUU
# 5456        Indie  My Morning Jacket          Z
# 5457         Rock  My Morning Jacket          Z
#
#                                              link_album
# 0         https://www.metacritic.com/music/()/sigur-ros
# 1         https://www.metacritic.com/music/()/sigur-ros
# 2     https://www.metacritic.com/music/(divide)/ed-s...
# 3         https://www.metacritic.com/music/+/ed-sheeran
# 4           https://www.metacritic.com/music/0304/jewel
# ...                                                 ...
# 5453  https://www.metacritic.com/music/zeitgeist/the...
# 5454  https://www.metacritic.com/music/zeitgeist/the...
# 5455  https://www.metacritic.com/music/zuu/denzel-curry
# 5456  https://www.metacritic.com/music/z/my-morning-...
# 5457  https://www.metacritic.com/music/z/my-morning-...
#
# [4355 rows x 4 columns]

# %% [markdown]
# # Clusterization

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import DistanceMetric

# %%
genres_matr = []
# all_data = {"artist": [], "album": [], "link_album": []}
all_data = {"link_album": []}
all_genres = df_genres["genre"].unique()

for g in all_genres:
    all_data[g] = []

for link in df_genres["link_album"].unique():
    rows_album = df_genres[df_genres["link_album"] == link]
    album = rows_album.iloc[0]
    genres_album = [r[0] for r in rows_album.values]
    # for key, val in [("artist", album[1]), ("album", album[2]), ("link_album", album[3])]:
    for key, val in [("link_album", album[3])]:
        all_data[key].append(val)
    for genre in all_genres:
        all_data[genre].append(1 if genre in genres_album else 0)

df_prep = pd.DataFrame.from_dict(all_data).set_index("link_album")
df_prep
# Out:
#                                                     Indie  Rock  Pop/Rock  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros           1     1         0
# https://www.metacritic.com/music/(divide)/ed-sh...      0     0         1
# https://www.metacritic.com/music/+/ed-sheeran           0     0         1
# https://www.metacritic.com/music/0304/jewel             0     0         0
# https://www.metacritic.com/music/1000-forms-of-...      0     0         0
# ...                                                   ...   ...       ...
# https://www.metacritic.com/music/ysiv/logic             0     0         0
# https://www.metacritic.com/music/ys/joanna-newsom       1     1         0
# https://www.metacritic.com/music/zeitgeist/the-...      0     1         0
# https://www.metacritic.com/music/zuu/denzel-curry       0     0         0
# https://www.metacritic.com/music/z/my-morning-j...      1     1         0
#
#                                                     Pop  Singer-Songwriter  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros         0                  0
# https://www.metacritic.com/music/(divide)/ed-sh...    0                  0
# https://www.metacritic.com/music/+/ed-sheeran         0                  0
# https://www.metacritic.com/music/0304/jewel           1                  1
# https://www.metacritic.com/music/1000-forms-of-...    0                  0
# ...                                                 ...                ...
# https://www.metacritic.com/music/ysiv/logic           0                  0
# https://www.metacritic.com/music/ys/joanna-newsom     0                  0
# https://www.metacritic.com/music/zeitgeist/the-...    0                  0
# https://www.metacritic.com/music/zuu/denzel-curry     0                  0
# https://www.metacritic.com/music/z/my-morning-j...    0                  0
#
#                                                     Electronic  Club/Dance  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros                0           0
# https://www.metacritic.com/music/(divide)/ed-sh...           0           0
# https://www.metacritic.com/music/+/ed-sheeran                0           0
# https://www.metacritic.com/music/0304/jewel                  0           0
# https://www.metacritic.com/music/1000-forms-of-...           1           1
# ...                                                        ...         ...
# https://www.metacritic.com/music/ysiv/logic                  0           0
# https://www.metacritic.com/music/ys/joanna-newsom            0           0
# https://www.metacritic.com/music/zeitgeist/the-...           0           0
# https://www.metacritic.com/music/zuu/denzel-curry            0           0
# https://www.metacritic.com/music/z/my-morning-j...           0           0
#
#                                                     Alternative  Metal  Rap  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros                 0      0    0
# https://www.metacritic.com/music/(divide)/ed-sh...            0      0    0
# https://www.metacritic.com/music/+/ed-sheeran                 0      0    0
# https://www.metacritic.com/music/0304/jewel                   0      0    0
# https://www.metacritic.com/music/1000-forms-of-...            0      0    0
# ...                                                         ...    ...  ...
# https://www.metacritic.com/music/ysiv/logic                   0      0    1
# https://www.metacritic.com/music/ys/joanna-newsom             0      0    0
# https://www.metacritic.com/music/zeitgeist/the-...            1      0    0
# https://www.metacritic.com/music/zuu/denzel-curry             0      0    1
# https://www.metacritic.com/music/z/my-morning-j...            0      0    0
#
#                                                     ...  \
# link_album                                          ...
# https://www.metacritic.com/music/()/sigur-ros       ...
# https://www.metacritic.com/music/(divide)/ed-sh...  ...
# https://www.metacritic.com/music/+/ed-sheeran       ...
# https://www.metacritic.com/music/0304/jewel         ...
# https://www.metacritic.com/music/1000-forms-of-...  ...
# ...                                                 ...
# https://www.metacritic.com/music/ysiv/logic         ...
# https://www.metacritic.com/music/ys/joanna-newsom   ...
# https://www.metacritic.com/music/zeitgeist/the-...  ...
# https://www.metacritic.com/music/zuu/denzel-curry   ...
# https://www.metacritic.com/music/z/my-morning-j...  ...
#
#                                                     Alternative Singer/Songwriter  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros                                   0
# https://www.metacritic.com/music/(divide)/ed-sh...                              0
# https://www.metacritic.com/music/+/ed-sheeran                                   0
# https://www.metacritic.com/music/0304/jewel                                     0
# https://www.metacritic.com/music/1000-forms-of-...                              0
# ...                                                                           ...
# https://www.metacritic.com/music/ysiv/logic                                     0
# https://www.metacritic.com/music/ys/joanna-newsom                               0
# https://www.metacritic.com/music/zeitgeist/the-...                              0
# https://www.metacritic.com/music/zuu/denzel-curry                               0
# https://www.metacritic.com/music/z/my-morning-j...                              0
#
#                                                     Country  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros             0
# https://www.metacritic.com/music/(divide)/ed-sh...        0
# https://www.metacritic.com/music/+/ed-sheeran             0
# https://www.metacritic.com/music/0304/jewel               0
# https://www.metacritic.com/music/1000-forms-of-...        0
# ...                                                     ...
# https://www.metacritic.com/music/ysiv/logic               0
# https://www.metacritic.com/music/ys/joanna-newsom         0
# https://www.metacritic.com/music/zeitgeist/the-...        0
# https://www.metacritic.com/music/zuu/denzel-curry         0
# https://www.metacritic.com/music/z/my-morning-j...        0
#
#                                                     Contemporary Country  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros                          0
# https://www.metacritic.com/music/(divide)/ed-sh...                     0
# https://www.metacritic.com/music/+/ed-sheeran                          0
# https://www.metacritic.com/music/0304/jewel                            0
# https://www.metacritic.com/music/1000-forms-of-...                     0
# ...                                                                  ...
# https://www.metacritic.com/music/ysiv/logic                            0
# https://www.metacritic.com/music/ys/joanna-newsom                      0
# https://www.metacritic.com/music/zeitgeist/the-...                     0
# https://www.metacritic.com/music/zuu/denzel-curry                      0
# https://www.metacritic.com/music/z/my-morning-j...                     0
#
#                                                     Contemporary Rap  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros                      0
# https://www.metacritic.com/music/(divide)/ed-sh...                 0
# https://www.metacritic.com/music/+/ed-sheeran                      0
# https://www.metacritic.com/music/0304/jewel                        0
# https://www.metacritic.com/music/1000-forms-of-...                 0
# ...                                                              ...
# https://www.metacritic.com/music/ysiv/logic                        1
# https://www.metacritic.com/music/ys/joanna-newsom                  0
# https://www.metacritic.com/music/zeitgeist/the-...                 0
# https://www.metacritic.com/music/zuu/denzel-curry                  0
# https://www.metacritic.com/music/z/my-morning-j...                 0
#
#                                                     Alternative Pop/Rock  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros                          0
# https://www.metacritic.com/music/(divide)/ed-sh...                     0
# https://www.metacritic.com/music/+/ed-sheeran                          0
# https://www.metacritic.com/music/0304/jewel                            0
# https://www.metacritic.com/music/1000-forms-of-...                     0
# ...                                                                  ...
# https://www.metacritic.com/music/ysiv/logic                            0
# https://www.metacritic.com/music/ys/joanna-newsom                      0
# https://www.metacritic.com/music/zeitgeist/the-...                     0
# https://www.metacritic.com/music/zuu/denzel-curry                      0
# https://www.metacritic.com/music/z/my-morning-j...                     0
#
#                                                     Country-Pop  Folk  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros                 0     0
# https://www.metacritic.com/music/(divide)/ed-sh...            0     0
# https://www.metacritic.com/music/+/ed-sheeran                 0     0
# https://www.metacritic.com/music/0304/jewel                   0     0
# https://www.metacritic.com/music/1000-forms-of-...            0     0
# ...                                                         ...   ...
# https://www.metacritic.com/music/ysiv/logic                   0     0
# https://www.metacritic.com/music/ys/joanna-newsom             0     1
# https://www.metacritic.com/music/zeitgeist/the-...            0     0
# https://www.metacritic.com/music/zuu/denzel-curry             0     0
# https://www.metacritic.com/music/z/my-morning-j...            0     0
#
#                                                     Hardcore Rap  Pop-Rap  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros                  0        0
# https://www.metacritic.com/music/(divide)/ed-sh...             0        0
# https://www.metacritic.com/music/+/ed-sheeran                  0        0
# https://www.metacritic.com/music/0304/jewel                    0        0
# https://www.metacritic.com/music/1000-forms-of-...             0        0
# ...                                                          ...      ...
# https://www.metacritic.com/music/ysiv/logic                    0        1
# https://www.metacritic.com/music/ys/joanna-newsom              0        0
# https://www.metacritic.com/music/zeitgeist/the-...             0        0
# https://www.metacritic.com/music/zuu/denzel-curry              0        0
# https://www.metacritic.com/music/z/my-morning-j...             0        0
#
#                                                     Southern Rap
# link_album
# https://www.metacritic.com/music/()/sigur-ros                  0
# https://www.metacritic.com/music/(divide)/ed-sh...             0
# https://www.metacritic.com/music/+/ed-sheeran                  0
# https://www.metacritic.com/music/0304/jewel                    0
# https://www.metacritic.com/music/1000-forms-of-...             0
# ...                                                          ...
# https://www.metacritic.com/music/ysiv/logic                    0
# https://www.metacritic.com/music/ys/joanna-newsom              0
# https://www.metacritic.com/music/zeitgeist/the-...             0
# https://www.metacritic.com/music/zuu/denzel-curry              0
# https://www.metacritic.com/music/z/my-morning-j...             0
#
# [2187 rows x 30 columns]

# %%
df_cocurrency_all = df_prep.T.dot(df_prep)
df_cocurrency = df_cocurrency_all.copy()
df_cocurrency
# Out:
#                                Indie  Rock  Pop/Rock  Pop  Singer-Songwriter  \
# Indie                            261   247         0   19                 13
# Rock                             247   641         0   99                 33
# Pop/Rock                           0     0       681   90                  0
# Pop                               19    99        90  292                  3
# Singer-Songwriter                 13    33         0    3                 43
# Electronic                        17    19        38   17                  0
# Club/Dance                         0     0        18   12                  0
# Alternative                       28   215         1   20                  3
# Metal                              0    54         4    0                  0
# Rap                                7     6        36   17                  0
# Heavy Metal                        0     0        50    2                  0
# Dance-Pop                          0     0        46   42                  0
# Contemporary Pop/Rock              0     0        51   15                  0
# Contemporary R&B                   0     0        29   29                  0
# R&B                                1     6        45   78                  1
# Dance                              4    13         0   20                  0
# Soul                               0     2        10   11                  1
# Adult Alternative Pop/Rock         0     0        39   11                  0
# Alternative/Indie Rock             0     1       258   16                  0
# Indie Rock                         0     0        45    1                  0
# Alternative Singer/Songwriter      0     0        32    3                  0
# Country                            1    13        38    6                  2
# Contemporary Country               0     0        18    3                  0
# Contemporary Rap                   0     0         3    2                  0
# Alternative Pop/Rock               0     0        96    3                  0
# Country-Pop                        0     0        13    1                  0
# Folk                               7    12        25    1                  5
# Hardcore Rap                       0     0        10    1                  0
# Pop-Rap                            0     0        10   11                  0
# Southern Rap                       0     0         8    0                  0
#
#                                Electronic  Club/Dance  Alternative  Metal  \
# Indie                                  17           0           28      0
# Rock                                   19           0          215     54
# Pop/Rock                               38          18            1      4
# Pop                                    17          12           20      0
# Singer-Songwriter                       0           0            3      0
# Electronic                            155          34           14      0
# Club/Dance                             34          38            0      0
# Alternative                            14           0          231     34
# Metal                                   0           0           34     61
# Rap                                     9           2            4      0
# Heavy Metal                             0           0            0      1
# Dance-Pop                               9          11            0      0
# Contemporary Pop/Rock                   0           0            0      0
# Contemporary R&B                        0           1            0      0
# R&B                                     5           3            0      0
# Dance                                  10           0            2      0
# Soul                                    2           0            0      0
# Adult Alternative Pop/Rock              0           0            0      0
# Alternative/Indie Rock                 14           6            0      0
# Indie Rock                              1           0            0      0
# Alternative Singer/Songwriter           1           1            0      0
# Country                                 0           0            6      0
# Contemporary Country                    0           0            0      0
# Contemporary Rap                        0           0            0      0
# Alternative Pop/Rock                    4           1            1      0
# Country-Pop                             0           0            0      0
# Folk                                    1           0            2      0
# Hardcore Rap                            0           0            0      0
# Pop-Rap                                 0           0            0      0
# Southern Rap                            0           0            0      0
#
#                                Rap  ...  Alternative Singer/Songwriter  \
# Indie                            7  ...                              0
# Rock                             6  ...                              0
# Pop/Rock                        36  ...                             32
# Pop                             17  ...                              3
# Singer-Songwriter                0  ...                              0
# Electronic                       9  ...                              1
# Club/Dance                       2  ...                              1
# Alternative                      4  ...                              0
# Metal                            0  ...                              0
# Rap                            407  ...                              0
# Heavy Metal                      0  ...                              0
# Dance-Pop                        3  ...                              0
# Contemporary Pop/Rock            0  ...                              3
# Contemporary R&B                10  ...                              0
# R&B                             29  ...                              0
# Dance                            1  ...                              0
# Soul                             2  ...                              0
# Adult Alternative Pop/Rock       0  ...                              9
# Alternative/Indie Rock           4  ...                             30
# Indie Rock                       1  ...                              7
# Alternative Singer/Songwriter    0  ...                             33
# Country                          0  ...                              2
# Contemporary Country             0  ...                              0
# Contemporary Rap                28  ...                              0
# Alternative Pop/Rock             4  ...                              9
# Country-Pop                      0  ...                              0
# Folk                             0  ...                              3
# Hardcore Rap                    39  ...                              0
# Pop-Rap                         29  ...                              0
# Southern Rap                    29  ...                              0
#
#                                Country  Contemporary Country  \
# Indie                                1                     0
# Rock                                13                     0
# Pop/Rock                            38                    18
# Pop                                  6                     3
# Singer-Songwriter                    2                     0
# Electronic                           0                     0
# Club/Dance                           0                     0
# Alternative                          6                     0
# Metal                                0                     0
# Rap                                  0                     0
# Heavy Metal                          0                     0
# Dance-Pop                            0                     0
# Contemporary Pop/Rock                6                     3
# Contemporary R&B                     0                     0
# R&B                                  2                     0
# Dance                                0                     0
# Soul                                 1                     0
# Adult Alternative Pop/Rock           1                     0
# Alternative/Indie Rock               8                     0
# Indie Rock                           1                     0
# Alternative Singer/Songwriter        2                     0
# Country                            190                    62
# Contemporary Country                62                    65
# Contemporary Rap                     0                     0
# Alternative Pop/Rock                 2                     0
# Country-Pop                         35                    31
# Folk                                 7                     1
# Hardcore Rap                         0                     0
# Pop-Rap                              0                     0
# Southern Rap                         0                     0
#
#                                Contemporary Rap  Alternative Pop/Rock  \
# Indie                                         0                     0
# Rock                                          0                     0
# Pop/Rock                                      3                    96
# Pop                                           2                     3
# Singer-Songwriter                             0                     0
# Electronic                                    0                     4
# Club/Dance                                    0                     1
# Alternative                                   0                     1
# Metal                                         0                     0
# Rap                                          28                     4
# Heavy Metal                                   0                     3
# Dance-Pop                                     0                     0
# Contemporary Pop/Rock                         0                     5
# Contemporary R&B                              4                     0
# R&B                                           1                     1
# Dance                                         0                     0
# Soul                                          0                     0
# Adult Alternative Pop/Rock                    0                     9
# Alternative/Indie Rock                        1                    96
# Indie Rock                                    0                    23
# Alternative Singer/Songwriter                 0                     9
# Country                                       0                     2
# Contemporary Country                          0                     0
# Contemporary Rap                             29                     1
# Alternative Pop/Rock                          1                   101
# Country-Pop                                   0                     0
# Folk                                          0                     4
# Hardcore Rap                                  8                     1
# Pop-Rap                                      11                     0
# Southern Rap                                  8                     0
#
#                                Country-Pop  Folk  Hardcore Rap  Pop-Rap  \
# Indie                                    0     7             0        0
# Rock                                     0    12             0        0
# Pop/Rock                                13    25            10       10
# Pop                                      1     1             1       11
# Singer-Songwriter                        0     5             0        0
# Electronic                               0     1             0        0
# Club/Dance                               0     0             0        0
# Alternative                              0     2             0        0
# Metal                                    0     0             0        0
# Rap                                      0     0            39       29
# Heavy Metal                              0     0             0        0
# Dance-Pop                                0     0             0        1
# Contemporary Pop/Rock                    5     0             0        0
# Contemporary R&B                         0     0             1        9
# R&B                                      0     1             0        5
# Dance                                    0     0             0        0
# Soul                                     1     0             0        0
# Adult Alternative Pop/Rock               0     1             0        0
# Alternative/Indie Rock                   0    13             1        0
# Indie Rock                               0     1             0        0
# Alternative Singer/Songwriter            0     3             0        0
# Country                                 35     7             0        0
# Contemporary Country                    31     1             0        0
# Contemporary Rap                         0     0             8       11
# Alternative Pop/Rock                     0     4             1        0
# Country-Pop                             37     0             0        0
# Folk                                     0    57             0        0
# Hardcore Rap                             0     0            40        6
# Pop-Rap                                  0     0             6       33
# Southern Rap                             0     0            15        0
#
#                                Southern Rap
# Indie                                     0
# Rock                                      0
# Pop/Rock                                  8
# Pop                                       0
# Singer-Songwriter                         0
# Electronic                                0
# Club/Dance                                0
# Alternative                               0
# Metal                                     0
# Rap                                      29
# Heavy Metal                               0
# Dance-Pop                                 0
# Contemporary Pop/Rock                     0
# Contemporary R&B                          0
# R&B                                       0
# Dance                                     0
# Soul                                      0
# Adult Alternative Pop/Rock                0
# Alternative/Indie Rock                    0
# Indie Rock                                0
# Alternative Singer/Songwriter             0
# Country                                   0
# Contemporary Country                      0
# Contemporary Rap                          8
# Alternative Pop/Rock                      0
# Country-Pop                               0
# Folk                                      0
# Hardcore Rap                             15
# Pop-Rap                                   0
# Southern Rap                             31
#
# [30 rows x 30 columns]

# %% [markdown]
# # Normalize values

# %%
df_cocurrency = (df_cocurrency-df_cocurrency.mean())/df_cocurrency.std()
df_cocurrency += df_cocurrency.T
df_cocurrency /= 2
np.fill_diagonal(df_cocurrency.values, 0)
df_cocurrency
# Out:
#                                   Indie      Rock  Pop/Rock       Pop  \
# Indie                          0.000000  2.564149 -0.378793 -0.084585
# Rock                           2.564149  0.000000 -0.399123  0.845197
# Pop/Rock                      -0.378793 -0.399123  0.000000  0.686225
# Pop                           -0.084585  0.845197  0.686225  0.000000
# Singer-Songwriter              0.429475  1.455508 -0.397695 -0.241283
# Electronic                     0.067592  0.023540  0.383631 -0.000876
# Club/Dance                    -0.376872 -0.397201  0.562273  0.264595
# Alternative                    0.143925  2.410882 -0.374615 -0.055028
# Metal                         -0.322617  1.604338 -0.241908 -0.409127
# Rap                           -0.206255 -0.264549  0.013225 -0.128721
# Heavy Metal                   -0.311913 -0.332243  1.717177 -0.304796
# Rock                              2.410882  1.604338 -0.264549  ...
# Pop/Rock                         -0.374615 -0.241908  0.013225  ...
# Pop                              -0.055028 -0.409127 -0.128721  ...
# Singer-Songwriter                -0.163363 -0.341519 -0.327359  ...
# Electronic                       -0.001389 -0.366980 -0.135938  ...
# Club/Dance                       -0.385502 -0.384204 -0.252905  ...
# Alternative                       0.000000  1.063754 -0.254388  ...
# Metal                             1.063754  0.000000 -0.315789  ...
# Rap                              -0.254388 -0.315789  0.000000  ...
# Heavy Metal                      -0.320544 -0.249172 -0.305086  ...
# Dance-Pop                        -0.412465 -0.411167 -0.275483  ...
# Contemporary Pop/Rock            -0.405228 -0.403930 -0.389770  ...
# Contemporary R&B                 -0.396499 -0.395201 -0.008944  ...
# R&B                              -0.364369 -0.363070  0.151226  ...
# Dance                            -0.207926 -0.361572 -0.272049  ...
# Soul                             -0.347546 -0.346248 -0.246966  ...
# Adult Alternative Pop/Rock       -0.398517 -0.397219 -0.383059  ...
# Alternative/Indie Rock           -0.371899 -0.370600 -0.299721  ...
# Indie Rock                       -0.370953 -0.369655 -0.314408  ...
# Alternative Singer/Songwriter    -0.397403 -0.396105 -0.381945  ...
# Country                          -0.206225 -0.341007 -0.326847  ...
# Contemporary Country             -0.347030 -0.345732 -0.331572  ...
# Contemporary Rap                 -0.381760 -0.380462  1.709144  ...
# Alternative Pop/Rock             -0.346946 -0.371567 -0.262166  ...
# Country-Pop                      -0.360018 -0.358720 -0.344560  ...
# Folk                             -0.268294 -0.373523 -0.359363  ...
# Hardcore Rap                     -0.364417 -0.363119  1.815828  ...
# Pop-Rap                          -0.398575 -0.397277  1.571016  ...
# Southern Rap                     -0.354694 -0.353395  1.658868  ...
#
#                                Alternative Singer/Songwriter   Country  \
# Indie                                              -0.388773 -0.312070
# Rock                                               -0.409103 -0.123756
# Pop/Rock                                            1.341359  0.275605
# Pop                                                -0.292244 -0.284185
# Singer-Songwriter                                  -0.407675 -0.223148
# Electronic                                         -0.363687 -0.378039
# Club/Dance                                         -0.346439 -0.395262
# Alternative                                        -0.397403 -0.206225
# Metal                                              -0.396105 -0.341007
# Rap                                                -0.381945 -0.326847
# Heavy Metal                                        -0.385402 -0.330304
# Dance-Pop                                          -0.477324 -0.422226
# Contemporary Pop/Rock                              -0.198677 -0.102247
# Contemporary R&B                                   -0.461357 -0.406259
# R&B                                                -0.429227 -0.325626
# Dance                                              -0.427729 -0.372631
# Soul                                               -0.412405 -0.307740
# Adult Alternative Pop/Rock                          0.383585 -0.352517
# Alternative/Indie Rock                              1.349185 -0.212178
# Indie Rock                                          0.169260 -0.332621
# Alternative Singer/Songwriter                       0.000000 -0.275317
# Country                                            -0.275317  0.000000
# Contemporary Country                               -0.411888  2.335300
# Contemporary Rap                                   -0.446618 -0.391520
# Alternative Pop/Rock                                0.184731 -0.320995
# Country-Pop                                        -0.424876  1.766744
# Folk                                               -0.150159  0.022542
# Hardcore Rap                                       -0.429276 -0.374178
# Pop-Rap                                            -0.463433 -0.408335
# Southern Rap                              -0.395014    -0.382167 -0.396970
#
#                                Hardcore Rap   Pop-Rap  Southern Rap
# Indie                             -0.355787 -0.389945     -0.346063
# Rock                              -0.376116 -0.410274     -0.366393
# Pop/Rock                           0.107110  0.191718      0.118695
# Pop                               -0.384695  0.287813     -0.432573
# Singer-Songwriter                 -0.374689 -0.408847     -0.364966
# Electronic                        -0.400150 -0.434308     -0.390427
# Club/Dance                        -0.417374 -0.451532     -0.407651
# Alternative                       -0.364417 -0.398575     -0.354694
# Metal                             -0.363119 -0.397277     -0.353395
# Rap                                1.815828  1.571016      1.658868
# Heavy Metal                       -0.352416 -0.386573     -0.342692
# Dance-Pop                         -0.444338 -0.384170     -0.434614
# Contemporary Pop/Rock             -0.437101 -0.471258     -0.427377
# Contemporary R&B                  -0.349220  0.356714     -0.418647
# R&B                               -0.396241 -0.075081     -0.386517
# Dance                             -0.394743 -0.428900     -0.385019
# Soul                              -0.379418 -0.413576     -0.369695
# Adult Alternative Pop/Rock        -0.430390 -0.464547     -0.420666
# Alternative/Indie Rock            -0.347650 -0.437929     -0.394047
# Indie Rock                        -0.402825 -0.436983     -0.393102
# Alternative Singer/Songwriter     -0.429276 -0.463433     -0.419552
# Country                           -0.374178 -0.408335     -0.364454
# Contemporary Country              -0.378902 -0.413060     -0.369178
# Contemporary Rap                   0.514879  0.959555      0.631745
# Alternative Pop/Rock              -0.338986 -0.438895     -0.395014
# Country-Pop                       -0.391890 -0.426048     -0.382167
# Folk                              -0.406693 -0.440851     -0.396970
# Hardcore Rap                       0.000000  0.225501      1.276049
# Pop-Rap                            0.225501  0.000000     -0.420724
# Southern Rap                       1.276049 -0.420724      0.000000
#
# [30 rows x 30 columns]

# %% [markdown]
# # Distance Matrix

# %%
dist = DistanceMetric.get_metric("euclidean")
df_dist = pd.DataFrame(dist.pairwise(df_cocurrency.to_numpy()), columns=df_cocurrency.columns, index=df_cocurrency.columns)
df_dist
# Out:
#                                   Indie      Rock  Pop/Rock       Pop  \
# Indie                          0.000000  4.938653  6.886068  3.713494
# Rock                           4.938653  0.000000  7.844083  5.572109
# Pop/Rock                       6.886068  7.844083  0.000000  5.775360
# Pop                            3.713494  5.572109  5.775360  0.000000
# Singer-Songwriter              1.436663  4.632458  6.558342  3.512375
# Electronic                     3.705783  5.170452  6.146397  3.169409
# Club/Dance                     3.965937  5.605759  6.095128  3.603433
# Alternative                    1.567377  4.694893  6.942534  3.929415
# Metal                          1.771416  4.640015  6.737972  3.642236
# Rap                            5.152710  6.454474  6.767603  4.839336
# Heavy Metal                    3.807635  5.479044  6.078139  3.561177
# Dance-Pop                      4.274795  5.675896  6.024249  3.082416
# Contemporary Pop/Rock          4.153039  5.747097  5.593716  3.324886
# Contemporary R&B               4.334947  5.790031  6.243776  2.753760
# R&B                            4.801510  6.043445  6.314245  3.559364
# Dance                          2.562733  4.717230  6.367846  3.423420
# Soul                           3.935144  5.548667  6.292295  3.175282
# Adult Alternative Pop/Rock     4.307342  5.880414  5.136618  3.977879
# Alternative/Indie Rock         5.811628  7.078270  5.042370  5.296586
# Contemporary Rap                   1.306362  1.960823      1.890028
# Alternative Pop/Rock               4.253719  4.111203      4.153592
# Country-Pop                        4.417654  4.278489      4.309796
# Folk                               3.312495  3.102782      3.183520
# Hardcore Rap                       0.000000  2.083764      1.930526
# Pop-Rap                            2.083764  0.000000      1.684152
# Southern Rap                       1.930526  1.684152      0.000000
#
# [30 rows x 30 columns]

# %%
with sns.axes_style("white"):
    fig, axes = plt.subplots(nrows=1, ncols=1)
    fig.set_figheight(13)
    fig.set_figwidth(13)

    mask = np.zeros_like(df_dist)
    mask[np.triu_indices_from(mask)] = True
    sns.heatmap(df_dist, mask=mask, ax=axes, cmap="YlGnBu") 
axes.set_title("Distance between genres (lower is similar)")

plt.show(fig)

# %%
from sklearn.cluster import KMeans

X = df_cocurrency.values

inertia = []
K = range(1,20)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X)
    inertia.append(kmeanModel.inertia_)

plt.plot(K, inertia, "bo-")
plt.plot(K[:-1], [0 if i == 0 else inertia[i+1]-inertia[i] for i in range(len(K)-1)], "ro--")
plt.xlabel("k")
plt.ylabel("Inertia")
plt.xticks([0, 5, 10, 15, 20])
plt.legend(["Inertia", "Inertia Delta"])

plt.show()

# %% [markdown]
# We choose 6 as the number of cluster, because it seems like an elbom

# %%
kmeans = KMeans(n_clusters=6).fit(X)

labels = pd.DataFrame(kmeans.labels_) # This is where the label output of the KMeans we just ran lives. Make it a dataframe so we can concatenate back to the original data
labelled_albuns = kmeans.predict(X)
clusters = {i: [] for i in set(labelled_albuns)}
for i, genre in enumerate(df_cocurrency.columns):
    clusters[labelled_albuns[i]].append(genre)

print(clusters)
# Out:
# {0: ['Pop/Rock'], 1: ['Pop', 'Electronic', 'Club/Dance', 'Dance-Pop', 'Contemporary R&B', 'R&B', 'Soul'], 2: ['Indie', 'Rock', 'Singer-Songwriter', 'Alternative', 'Metal', 'Dance'], 3: ['Heavy Metal', 'Contemporary Pop/Rock', 'Adult Alternative Pop/Rock', 'Alternative/Indie Rock', 'Indie Rock', 'Alternative Singer/Songwriter', 'Alternative Pop/Rock', 'Folk'], 4: ['Rap', 'Contemporary Rap', 'Hardcore Rap', 'Pop-Rap', 'Southern Rap'], 5: ['Country', 'Contemporary Country', 'Country-Pop']}

# %%
pop_rb = next(i for i, genres in clusters.items() if "Pop" in genres)
rap = next(i for i, genres in clusters.items() if "Rap" in genres)
country = next(i for i, genres in clusters.items() if "Country" in genres)
mainstream_rock = next(i for i, genres in clusters.items() if "Indie" in genres)
rock_subgenres = next(i for i, genres in clusters.items() if "Folk" in genres)
pop_rock = next(i for i, genres in clusters.items() if "Pop/Rock" in genres)

clustes_descr = {
    pop_rb: "Pop, R&B, Dance",
    rap: "Rap",
    rock_subgenres: "Rock Subgenres",
    mainstream_rock: "Mainstream Rock",
    country: "Country",
    pop_rock: "Pop/Rock"
}

# %% [markdown]
# # SVD (Singular Value Decomposition)

# %%
u, s, v = np.linalg.svd(X, full_matrices=True)

var_explained = np.round(s**2/np.sum(s**2), decimals=3)
print(var_explained)
 
sns.barplot(x=list(range(1,len(var_explained[:20])+1)),
            y=var_explained[:20], color="limegreen")
plt.xlabel('SVs')
plt.ylabel('Percent Variance Explained')
plt.title("Eigenvalues for Eigenvectors")
plt.show()
# Out:
# [0.205 0.19  0.134 0.101 0.086 0.055 0.032 0.029 0.029 0.022 0.02  0.019
#  0.014 0.012 0.011 0.008 0.006 0.005 0.005 0.004 0.003 0.003 0.002 0.002
#  0.002 0.001 0.001 0.    0.    0.   ]

# %%
labels= ['SV'+str(i) for i in range(1,3)]
svd_df = pd.DataFrame(u[:,0:2], index=df_cocurrency.columns.tolist(), columns=labels)
svd_df = svd_df.reset_index()
svd_df.rename(columns={'index': 'Genre'}, inplace=True)
svd_df["label"] = kmeans.labels_
svd_df["descr"] = [clustes_descr[v] for v in svd_df["label"]]
svd_df["ocurr"] = [df_cocurrency_all.iloc[i, i] for i in range(len(svd_df))]
svd_df
# Out:
#                             Genre       SV1       SV2  label            descr  \
# 0                           Indie  0.191516  0.159195      2  Mainstream Rock
# 1                            Rock  0.287826 -0.057463      2  Mainstream Rock
# 2                        Pop/Rock -0.462918 -0.377499      0         Pop/Rock
# 3                             Pop  0.014895  0.042737      1  Pop, R&B, Dance
# 4               Singer-Songwriter  0.142082  0.175793      2  Mainstream Rock
# 5                      Electronic  0.007755  0.132132      1  Pop, R&B, Dance
# 6                      Club/Dance -0.039917  0.188741      1  Pop, R&B, Dance
# 7                     Alternative  0.200665  0.152070      2  Mainstream Rock
# 8                           Metal  0.150995  0.186545      2  Mainstream Rock
# 9                             Rap  0.120753 -0.006422      4              Rap
# 10                    Heavy Metal -0.119622  0.277080      3   Rock Subgenres
# 11                      Dance-Pop -0.071512  0.216678      1  Pop, R&B, Dance
# 12          Contemporary Pop/Rock -0.178690  0.227455      3   Rock Subgenres
# 13               Contemporary R&B  0.007574  0.177247      1  Pop, R&B, Dance
# 14                            R&B  0.022804  0.067762      1  Pop, R&B, Dance
# 15                          Dance  0.106580  0.182854      2  Mainstream Rock
# 16                           Soul  0.023455  0.174773      1  Pop, R&B, Dance
# 17     Adult Alternative Pop/Rock -0.249443  0.217604      3   Rock Subgenres
# 18         Alternative/Indie Rock -0.439199  0.064161      3   Rock Subgenres
# 19                     Indie Rock -0.245214  0.224706      3   Rock Subgenres
# 20  Alternative Singer/Songwriter -0.250404  0.219066      3   Rock Subgenres
# 21                        Country -0.006841  0.105092      5          Country
# 22           Contemporary Country  0.003344  0.139393      5          Country
# 23               Contemporary Rap  0.105600  0.140606      4              Rap
# 24           Alternative Pop/Rock -0.300851  0.196842      3   Rock Subgenres
# 25                    Country-Pop -0.001803  0.155088      5          Country
# 26                           Folk -0.045004  0.224945      3   Rock Subgenres
# 27                   Hardcore Rap  0.087649  0.162744      4              Rap
# 28                        Pop-Rap  0.078036  0.192629      4              Rap
# 29                   Southern Rap  0.084641  0.180104      4              Rap
#
#     ocurr
# 0     261
# 1     641
# 2     681
# 3     292
# 4      43
# 5     155
# 6      38
# 7     231
# 8      61
# 9     407
# 10     54
# 11     55
# 12     52
# 13     65
# 14    248
# 15     33
# 16     58
# 17     41
# 18    273
# 19     50
# 20     33
# 21    190
# 22     65
# 23     29
# 24    101
# 25     37
# 26     57
# 27     40
# 28     33
# 29     31

# %%
# specify colors for each continent
color_dict = {
    0: 'Blue',
    1: 'Orange',
    2: 'Yellow',
    3: 'Red',
    4: 'Black',
    5: 'Green',
}

with sns.axes_style("white"):
    fig, axes = plt.subplots(nrows=1, ncols=1)
    fig.set_figheight(8)
    fig.set_figwidth(8)
    # Scatter plot: SV1 and SV2
    sns.scatterplot(x="SV1", y="SV2", 
                    hue="descr",
                    size="ocurr",
                    sizes=(50, 300),
                    # palette=color_dict, 
                    data=svd_df,
                    alpha=0.7, ax=axes)
    axes.set_xlabel('SV 1: {0}%'.format(var_explained[0]*100))
    axes.set_ylabel('SV 2: {0}%'.format(var_explained[1]*100))
    plt.show(fig)

# %% [markdown]
# # Save data

# %%
# Save cluster centers and genres in it

clusters_centers = kmeans.cluster_centers_
genres_cluster = {clustes_descr[i]: {
    "genres": clusters[i], "center": clusters_centers[i]} for i in clusters}

df_clusters = pd.DataFrame.from_dict(genres_cluster)
df_clusters.to_json("genres_clusters.json")

# %%
# Save albums distance to clusters

df = pd.read_json(filename, convert_dates=["release_date"])
df.reset_index(inplace=True)

df_genres_albums = df[["link_album", "genres"]]

# Function to get genres position, using average from genres
def get_genres_pos(genres: List[str]):
    genres = [g for g in genres if g in df_cocurrency.columns]
    if(len(genres) == 0):
        return None

    arr = df_cocurrency[genres[0]].values.copy()
    for g in genres[1:]:
        arr += df_cocurrency[g].values.copy()
    return arr / len(genres)

# %%
from scipy.spatial import distance

# Dictionary with data to save
dct_albums_cluster_dist = {"link_album": []} 
# Cluster to measure distance
for c in genres_cluster:
    dct_albums_cluster_dist[c] = []

# For each album
for idx, row in df_genres_albums.iterrows():
    link_album, genres = row["link_album"], row["genres"]
    if(genres is None):
        continue
    album_pos = get_genres_pos(genres)
    if(album_pos is None):
        continue
    album_distances = {}
    # For each cluster, measure euclidean distance from genre
    for c, val in genres_cluster.items():
        center = val["center"]
        cluster_distance = distance.euclidean(center, album_pos)
        album_distances[c] = cluster_distance
        
    # Add data to dictionary
    dct_albums_cluster_dist["link_album"].append(link_album)
    for c, val in album_distances.items():
        dct_albums_cluster_dist[c].append(album_distances[c])

df_albums_cluster_dist = pd.DataFrame.from_dict(dct_albums_cluster_dist)
df_albums_cluster_dist = df_albums_cluster_dist.reset_index(drop=True)
df_albums_cluster_dist = df_albums_cluster_dist.set_index("link_album")
df_albums_cluster_dist
# Out:
#                                                         Pop/Rock  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros       6.955301e+00
# https://www.metacritic.com/music/(divide)/ed-sh...  2.588868e-16
# https://www.metacritic.com/music/+/ed-sheeran       2.588868e-16
# https://www.metacritic.com/music/0304/jewel         5.924451e+00
# https://www.metacritic.com/music/0307-0907/high...  6.146397e+00
# ...                                                          ...
# https://www.metacritic.com/music/ys/joanna-newsom   6.471314e+00
# https://www.metacritic.com/music/zeitgeist/the-...  7.025219e+00
# https://www.metacritic.com/music/zoy-zoy/tal-na...  2.588868e-16
# https://www.metacritic.com/music/zuu/denzel-curry   6.767603e+00
# https://www.metacritic.com/music/z/my-morning-j...  6.955301e+00
#
#                                                     Pop, R&B, Dance  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros              3.691394
# https://www.metacritic.com/music/(divide)/ed-sh...         5.738752
# https://www.metacritic.com/music/+/ed-sheeran              5.738752
# https://www.metacritic.com/music/0304/jewel                1.768242
# https://www.metacritic.com/music/0307-0907/high...         2.363362
# ...                                                             ...
# https://www.metacritic.com/music/ys/joanna-newsom          2.945806
# https://www.metacritic.com/music/zeitgeist/the-...         3.817040
# https://www.metacritic.com/music/zoy-zoy/tal-na...         5.738752
# https://www.metacritic.com/music/zuu/denzel-curry          4.296042
# https://www.metacritic.com/music/z/my-morning-j...         3.691394
#
#                                                     Mainstream Rock  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros              1.475995
# https://www.metacritic.com/music/(divide)/ed-sh...         6.590644
# https://www.metacritic.com/music/+/ed-sheeran              6.590644
# https://www.metacritic.com/music/0304/jewel                1.899011
# https://www.metacritic.com/music/0307-0907/high...         3.132415
# ...                                                             ...
# https://www.metacritic.com/music/ys/joanna-newsom          0.990551
# https://www.metacritic.com/music/zeitgeist/the-...         1.663753
# https://www.metacritic.com/music/zoy-zoy/tal-na...         6.590644
# https://www.metacritic.com/music/zuu/denzel-curry          4.753977
# https://www.metacritic.com/music/z/my-morning-j...         1.475995
#
#                                                     Rock Subgenres       Rap  \
# link_album
# https://www.metacritic.com/music/()/sigur-ros             4.248620  4.360133
# https://www.metacritic.com/music/(divide)/ed-sh...        5.191830  6.456137
# https://www.metacritic.com/music/+/ed-sheeran             5.191830  6.456137
# https://www.metacritic.com/music/0304/jewel               3.029042  3.346208
# https://www.metacritic.com/music/0307-0907/high...        3.200068  3.744627
# ...                                                            ...       ...
# https://www.metacritic.com/music/ys/joanna-newsom         3.260847  3.699107
# https://www.metacritic.com/music/zeitgeist/the-...        4.343998  4.456960
# https://www.metacritic.com/music/zoy-zoy/tal-na...        5.191830  6.456137
# https://www.metacritic.com/music/zuu/denzel-curry         4.809015  2.534851
# https://www.metacritic.com/music/z/my-morning-j...        4.248620  4.360133
#
#                                                      Country
# link_album
# https://www.metacritic.com/music/()/sigur-ros       4.494957
# https://www.metacritic.com/music/(divide)/ed-sh...  6.374708
# https://www.metacritic.com/music/+/ed-sheeran       6.374708
# https://www.metacritic.com/music/0304/jewel         3.671579
# https://www.metacritic.com/music/0307-0907/high...  4.044630
# ...                                                      ...
# https://www.metacritic.com/music/ys/joanna-newsom   3.774609
# https://www.metacritic.com/music/zeitgeist/the-...  4.567814
# https://www.metacritic.com/music/zoy-zoy/tal-na...  6.374708
# https://www.metacritic.com/music/zuu/denzel-curry   5.181266
# https://www.metacritic.com/music/z/my-morning-j...  4.494957
#
# [3155 rows x 6 columns]

# %%
df_albums_cluster_dist.to_csv("albums_dist_to_clusters.csv")
